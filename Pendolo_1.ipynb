# %%
using Statistics
using Plots

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.40
L = 1.10
# 1 periodo

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [2.08, 1.92, 2.04, 1.94, 1.97, 2.1, 2.09, 2.12, 2.28, 2.11, 2.14, 2.1, 2.12, 2.12, 2.08, 2.16, 2.1, 2.13, 2.06, 2.03, 2.08, 2.24, 2, 2.14, 2.08, 1.97, 1.92, 2.09, 1.96, 2.12, ]
# Out:
# L'angolo è 29.74488129694223
# 30-element Vector{Float64}:
#  2.08
#  1.92
#  2.04
#  1.94
#  1.97
#  2.1
#  2.09
#  2.12
#  2.28
#  2.11
#  2.14
#  2.1
#  2.12
#  ⋮
#  2.06
#  2.03
#  2.08
#  2.24
#  2.0
#  2.14
#  2.08
#  1.97
#  1.92
#  2.09
#  1.96
#  2.12

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 2.0763333333333334
# La deviazione standard è 0.08515638082611487

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
g = 4 * π^2 * L / media^2
println("Il valore misurato di g senza correzioni è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato di g senza correzioni è 10.072986909688437 m/s^2
# Il valore misurato di g con correzioni è 10.242661770787626 m/s^2

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.40
L = 1.10
# 2 periodo

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [4.34, 4.18, 4.08, 4.2, 4.04, 4.41, 4.18, 4.2, 4.09, 4.16, 4.14, 4.22, 4.17, 4.2, 4.12, 4.12, 4.41, 4.16, 4.31, 4.01, 3.82, 4.08, 4.14, 4.04, 3.94, 3.92, 3.88, 4.01, 4.31, 4.04, ]
# Out:
# L'angolo è 29.74488129694223
# 30-element Vector{Float64}:
#  4.34
#  4.18
#  4.08
#  4.2
#  4.04
#  4.41
#  4.18
#  4.2
#  4.09
#  4.16
#  4.14
#  4.22
#  4.17
#  ⋮
#  4.31
#  4.01
#  3.82
#  4.08
#  4.14
#  4.04
#  3.94
#  3.92
#  3.88
#  4.01
#  4.31
#  4.04

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 4.130666666666667
# La deviazione standard è 0.14333306602487775

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
media = media / 2
g = 4 * π^2 * L / media^2
println("Il valore misurato senza correzioni di g è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato senza correzioni di g è 10.180570439328879 m/s^2
# Il valore misurato di g con correzioni è 10.352057495818766 m/s^2

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.40
L = 1.10
# 4 periodi

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [8.33, 8.33, 8.63, 8.22, 8.43, 8.5, 8.28, 8.65, 8.46, 8.63, 8.37, 8.55, 8.38, 8.39, 8.39, 8.33, 8.4, 8.47, 8.38, 8.47, 8.34, 8.55, 8.41, 8.28, 8.69, 8.59, 8.08, 8.51, 8.41, 8.41, ]
# Out:
# L'angolo è 29.74488129694223
# 30-element Vector{Float64}:
#  8.33
#  8.33
#  8.63
#  8.22
#  8.43
#  8.5
#  8.28
#  8.65
#  8.46
#  8.63
#  8.37
#  8.55
#  8.38
#  ⋮
#  8.38
#  8.47
#  8.34
#  8.55
#  8.41
#  8.28
#  8.69
#  8.59
#  8.08
#  8.51
#  8.41
#  8.41

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 8.428666666666667
# La deviazione standard è 0.1351048975179411

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
media = media / 4
g = 4 * π^2 * L / media^2
println("Il valore misurato senza correzioni di g è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato senza correzioni di g è 9.780355630472497 m/s^2
# Il valore misurato di g con correzioni è 9.945101251406935 m/s^2

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.40
L = 1.10
# 8 periodi

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [16.93, 16.71, 17.11, 16.64, 17.06, 17.14, 16.87, 17.18, 17.22, 17.21, 17.04, 17.19, 16.92, 16.89, 16.87, 16.91, 16.92, 17.12, 17.06, 16.93, 16.83, 16.83, 17.09, 16.8, 17.29, 17.11, 16.41, 17.01, 16.94, 17.04, ]
# Out:
# L'angolo è 29.74488129694223
# 30-element Vector{Float64}:
#  16.93
#  16.71
#  17.11
#  16.64
#  17.06
#  17.14
#  16.87
#  17.18
#  17.22
#  17.21
#  17.04
#  17.19
#  16.92
#   ⋮
#  17.06
#  16.93
#  16.83
#  16.83
#  17.09
#  16.8
#  17.29
#  17.11
#  16.41
#  17.01
#  16.94
#  17.04

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 16.97566666666667
# La deviazione standard è 0.18973090441979648

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
media = media / 8
g = 4 * π^2 * L / media^2
println("Il valore misurato senza correzioni di g è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato senza correzioni di g è 9.644477808712917 m/s^2
# Il valore misurato di g con correzioni è 9.806934629836512 m/s^2

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.20
L = 1.10
# 1 periodo

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [2.1, 2.2, 1.8, 1.7, 2.08, 1.94, 1.98, 1.92, 1.88, 1.88, 1.89, 1.74, 1.96, 1.86, 1.79, 2, 1.97, 1.72, 2.13, 1.82, 1.96, 2, 2.06, 1.8, 2.04, 2, 1.86, 1.88, 2.11, 1.85, ]
# Out:
# L'angolo è 15.945395900922858
# 30-element Vector{Float64}:
#  2.1
#  2.2
#  1.8
#  1.7
#  2.08
#  1.94
#  1.98
#  1.92
#  1.88
#  1.88
#  1.89
#  1.74
#  1.96
#  ⋮
#  2.13
#  1.82
#  1.96
#  2.0
#  2.06
#  1.8
#  2.04
#  2.0
#  1.86
#  1.88
#  2.11
#  1.85

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 1.930666666666667
# La deviazione standard è 0.12735866631312323

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
g = 4 * π^2 * L / media^2
println("Il valore misurato senza correzioni di g è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato senza correzioni di g è 11.65031921181824 m/s^2
# Il valore misurato di g con correzioni è 11.706714548101763 m/s^2

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.20
L = 1.50
# 3 periodi

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [7.46, 7.11, 7.25, 7.24, 7.02, 7.18, 7.3, 7.12, 7.09, 7.07, 7.02, 6.96, 7.2, 6.89, 7.17, 6.86, 6.88, 7.16, 6.9, 7.1, 7.16, 7.08, 7.28, 7.04, 7.26, 7.18, 7.09, 7.33, 7.2, 7.12, ]
# Out:
# L'angolo è 15.945395900922858
# 30-element Vector{Float64}:
#  7.46
#  7.11
#  7.25
#  7.24
#  7.02
#  7.18
#  7.3
#  7.12
#  7.09
#  7.07
#  7.02
#  6.96
#  7.2
#  ⋮
#  6.9
#  7.1
#  7.16
#  7.08
#  7.28
#  7.04
#  7.26
#  7.18
#  7.09
#  7.33
#  7.2
#  7.12

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 7.124
# La deviazione standard è 0.1412652188932772

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
media = media / 3
g = 4 * π^2 * L / media^2
println("Il valore misurato senza correzioni di g è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato senza correzioni di g è 10.501363306067313 m/s^2
# Il valore misurato di g con correzioni è 10.552196927388207 m/s^2

# %%
# ----------------------------------- NUOVA MISURAZIONE ---------------------------------------------------------------------------------------------------

# %%
# parametri della misurazione
h = 0.70
b1 = 0.70
L = 1.50
# 3 periodi

theta = atan(b1/h)

println("L'angolo è ", theta * 180 / π)
x = [6.28, 6.14, 6.55, 6.21, 6.36, 6.38, 6.36, 6.42, 6.34, 6.48, 6.52, 6.54, 6.54, 6.2, 6.47, 6.34, 6.44, 6.27, 6.4, 6.28, 6.4, 6.36, 6.27, 6.38, 6.38, 6.46, 6.39, 6.38, 6.34, 6.34, ]
# Out:
# L'angolo è 45.0
# 30-element Vector{Float64}:
#  6.28
#  6.14
#  6.55
#  6.21
#  6.36
#  6.38
#  6.36
#  6.42
#  6.34
#  6.48
#  6.52
#  6.54
#  6.54
#  ⋮
#  6.4
#  6.28
#  6.4
#  6.36
#  6.27
#  6.38
#  6.38
#  6.46
#  6.39
#  6.38
#  6.34
#  6.34

# %%
media = mean(x)
println("La media è ", media)
deviazione_standard = std(x)
println("La deviazione standard è ", deviazione_standard)
# Out:
# La media è 6.3740000000000006
# La deviazione standard è 0.10169596336884393

# %%
# istogramma delle misure
histogram(x, bins = 10, xlabel = "Tempo (s)", ylabel="Numero di misure", label="Misure ottenute")

# %%
# distribuzione temporale delle misure
f(i) = media
d(i) = deviazione_standard + media
d2(i) = -deviazione_standard + media
plot(x, seriestype=:scatter, label="", xlabel = "Numero misura", ylabel="Valore ottenuto (Tempo (s))")
plot!(x, label="")
plot!(f, label ="")
plot!(d, label ="", ls = :dash)
plot!(d2, label ="", ls = :dash)

# %%
media = media / 3
g = 4 * π^2 * L / media^2
println("Il valore misurato senza correzioni di g è ", g, " m/s^2")
g = g * (1+theta^2/16)
println("Il valore misurato di g con correzioni è ", g, " m/s^2")
# Out:
# Il valore misurato senza correzioni di g è 13.11805317262525 m/s^2
# Il valore misurato di g con correzioni è 13.62379534186848 m/s^2
